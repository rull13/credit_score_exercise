# %% [markdown]
# # Model Selection & Evaluation

# %% [markdown]
# 1. What is model selection?
# 2. Consideration for model selection?
# 3. Model selection techniques
# ___
#
#   **__what is model selection?__**
#   Model selection is the task of selecting a statistical model from a set of candidate models, given data.
#
#   In the simplest cases, a pre-existing set of data is considered. However, the task can also involve the design of experiments such that the data collected is well-suited to the problem of model selection.
#
#   Model selection is a process that can be applied both:
#   1. **across different types of models (e.g. logistic regression, SVM, KNN, etc.)**
#   2. and **across models of the same type configured with different model hyperparameters (e.g. different kernels in an SVM)**.
#
# ___
#   > When we have a variety of models of different complexity (e.g., linear or logistic regression models with different degree polynomials, or KNN classifiers with different values of K), how should we pick the right one? .
#   [page 22 - Machine Learning - Probabilistic Prespective](https://www.amazon.com/Machine-Learning-Probabilistic-Perspective-Computation/dp/0262018020/ref=as_li_ss_tl?keywords=Machine+Learning+-+A+Probabilistic+Perspective&qid=1568233495&s=gateway&sr=8-1&linkCode=sl1&tag=inspiredalgor-20&linkId=36f0b3ee1e8fd4b4a723f96894af54a5&language=en_US)
#
#   **Consideration for model selection**.
#   1. The accuracy of the model.
#   2. The interpretability of the model.
#   3. The complexity of the model.
#   4. The scalability of the model.
#   5. How long does it take to build, train, and test the model?
#   6. How long does it take to make predictions using the model?
#   7.Does the model meet the business goal?
#
#
#   Some algorithms require specialized data preparation in order to best expose the structure of the problem to the learning algorithm. Therefore, we must go one step further and consider model selection as the process of selecting among model development pipelines.
#
# Each pipeline may take in the same raw training dataset and outputs a model that can be evaluated in the same manner but may require different or overlapping computational steps, such as:
#
# Data filtering.
# Data transformation.
# Feature selection.
# Feature engineering.
# And more…
#
#
#   **Model Selection Techniques**.
#   1. Probabilistic Measures: Choose a model via **in-sample error and complexity**.
#   2. Resampling Methods: Choose a model via **estimated out-of-sample error**.

# %% [markdown]
# ## Resampling Method: Train, Valid, Test

# %% [markdown]
# Describe more
#
# 1. Splitting Data: Train, Valid, Test
#     a. Random sample
#     b. Stratified sample.
# 2. Cross-Validation.
#     a. K-fold.
#     b. Stratified K-fold.
#     c. LOOCV - Leave One Out Cross Validated

# %% [markdown]
# # Load Dataset

# %% [markdown]
# 1. Load Data
# 2. Check your data: data types, missing data
# 3. Check simple statistic from your data
# 4. Let's think what tools that we will try. Data Preprocessing Pla, Model Plan

# %%
import numpy as np
import pandas as pd  # import pandas for data manipulation
pd.options.display.max_columns = None  # set options max_columns to None to display all columns

data = pd.read_csv('data/german_credit_data.csv', index_col=0)

# %%
data.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
data.shape
# Out:
# (1000, 10)

# %%
data.dtypes
# Out:
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# Risk                object
# dtype: object

# %%
y = data['Risk'].copy()
X = data.drop(columns='Risk').copy()

# %%
num_columns = X.select_dtypes(include='number').columns.tolist()
cat_columns = X.select_dtypes(include='object').columns.tolist()

print("Total numerical columns :", len(num_columns))
print("Total categorical columns :", len(cat_columns))
# Out:
# Total numerical columns : 4
# Total categorical columns : 5

# %%
num_idx = [X.columns.get_loc(c) for c in num_columns]
cat_idx = [X.columns.get_loc(c) for c in cat_columns]

# %%
X.columns[num_idx]
# Out:
# Index(['Age', 'Job', 'Credit amount', 'Duration'], dtype='object')

# %%
X.columns[cat_idx]
# Out:
# Index(['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose'], dtype='object')

# %%
for col in cat_columns + ['Job']:
    print(f"{col:<20}: {data[col].unique().tolist()}")
# Out:
# Sex                 : ['male', 'female']
# Housing             : ['own', 'free', 'rent']
# Saving accounts     : [nan, 'little', 'quite rich', 'rich', 'moderate']
# Checking account    : ['little', 'moderate', nan, 'rich']
# Purpose             : ['radio/TV', 'education', 'furniture/equipment', 'car', 'business', 'domestic appliances', 'repairs', 'vacation/others']
# Job                 : [2, 1, 3, 0]

# %% [markdown]
# ### Simple Statistics

# %%
X.describe(include='number').T
# Out:
#                 count      mean          std    min     25%     50%      75%  \
# Age            1000.0    35.546    11.375469   19.0    27.0    33.0    42.00
# Job            1000.0     1.904     0.653614    0.0     2.0     2.0     2.00
# Credit amount  1000.0  3271.258  2822.736876  250.0  1365.5  2319.5  3972.25
# Duration       1000.0    20.903    12.058814    4.0    12.0    18.0    24.00
#
#                    max
# Age               75.0
# Job                3.0
# Credit amount  18424.0
# Duration          72.0

# %%
X.describe(include='object').T
# Out:
#                  count unique     top freq
# Sex               1000      2    male  690
# Housing           1000      3     own  713
# Saving accounts    817      4  little  603
# Checking account   606      3  little  274
# Purpose           1000      8     car  337

# %%
y.value_counts()
# Out:
# good    700
# bad     300
# Name: Risk, dtype: int64

# %% [markdown]
# ### Check missing value

# %%
X.isnull().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
y = y.map({"good":0, "bad":1})

# %% [markdown]
# ## Correlated Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_correlation(data):
    corr = data.corr()
    mask = np.triu(np.ones_like(corr, dtype=bool))

    fig = plt.figure(figsize=(10, 10))

    ax = sns.heatmap(
        corr, 
        mask=mask,
        vmin=-1, vmax=1, center=0,
        cmap='coolwarm',
        square=True,
        linewidths=0.3,
        annot=True,
        fmt=".2f",
        annot_kws={"size": 8},
        cbar_kws={"shrink": .5}
    )

    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        horizontalalignment='right'
    )

    ax.set_title("Correlation", size=14)

    plt.show()

# %%
plot_correlation(X[num_columns])

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# ### Model Validation
#
# ![alt text](Capture2.PNG)
#
# ___
#
# 1. Training Dataset: The sample of data used to fit the model
# 2. Validation Dataset: The sample of data used to provide an unbiased evaluation of a model fit on the training  dataset while tuning model hyperparameters. The evaluation becomes more biased as skill on the validation dataset is incorporated into the model configuration
# 3. Test Dataset: The sample of data used to provide an unbiased evaluation of a final model fit on the training dataset.
#
# Some models need substantial data to train upon, so you would optimize for the more extensive training sets in this case.
# * Models with very few hyper-parameters will be easy to validate and tune, so you can probably reduce the size of your validation set.
# * But if your model has many hyper-parameters, you would want to have a significant validation set as well.
# * If you happen to have a model with no hyper-parameters or ones that cannot be easily tuned, you probably don’t need a validation set too.

# %% [markdown]
# **Random Sampling**
#
# Most typical splitting is random sampling. We split the dataset randomly for **unbiased evaluation**.
# </br></br>First we split our data to train and test (holdout sample).
# Typical splitting proportion in train and test.

# %% [markdown]
# train 60 valid20 test 20

# %%
# from sklearn.model_selection import train_test_split


# SEED = 42 # random number

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED)


# print("Number of Train :", len(y_train), f"{round(len(y_train) / len(y) * 100, 2)}%")
# print("Number of Test :", len(y_test), f"{round(len(y_test) / len(y) * 100, 2)}%")
# Out:
# Number of Train : 700 70.0%
# Number of Test : 300 30.0%

# %%
# print("Percentage of target in Train :", np.mean(y_train))
# print("Percentage of target in Test :", np.mean(y_test))
# Out:
# Percentage of target in Train : 0.2985714285714286
# Percentage of target in Test : 0.30333333333333334

# %% [markdown]
# <b>Parameter in train_test_split:</b>
#
# test_size : float, int or None, optional (default=0.25)
#     If float, should be between 0.0 and 1.0 and represent the proportion
#     of the dataset to include in the test split. If int, represents the
#     absolute number of test samples. If None, the value is set to the
#     complement of the train size. By default, the value is set to 0.25.
#     The default will change in version 0.21. It will remain 0.25 only
#     if ``train_size`` is unspecified, otherwise it will complement
#     the specified ``train_size``.
#
# train_size : float, int, or None, (default=None)
#     If float, should be between 0.0 and 1.0 and represent the
#     proportion of the dataset to include in the train split. If
#     int, represents the absolute number of train samples. If None,
#     the value is automatically set to the complement of the test size.
#
# random_state : int, RandomState instance or None, optional (default=None)
#     If int, random_state is the seed used by the random number generator;
#     If RandomState instance, random_state is the random number generator;
#     If None, the random number generator is the RandomState instance used
#     by `np.random`.
#
# shuffle : boolean, optional (default=True)
#     Whether or not to shuffle the data before splitting. If shuffle=False
#     then stratify must be None.
#
# stratify : array-like or None (default=None)
#     If not None, data is split in a stratified fashion, using this as
#     the class labels.

# %% [markdown]
# **Stratified Sampling**
#
# <img src='stratified-sampling.jpeg'>

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=SEED)

print("Number of Train :", len(y_train), f"{round(len(y_train) / len(y) * 100, 2)}%")
print("Number of Test :", len(y_test), f"{round(len(y_test) / len(y) * 100, 2)}%")
# Out:
# Number of Train : 700 70.0%
# Number of Test : 300 30.0%

# %%
print("Percentage of target in Train :", np.mean(y_train))
print("Percentage of target in Test :", np.mean(y_test))
# Out:
# Percentage of target in Train : 0.3
# Percentage of target in Test : 0.3

# %%
# X_train

# %%
# X_train.to_csv('X_train.csv')
# y_train.to_csv('y_train.csv')
# X_test.to_csv('X_test.csv')
# y_test.to_csv('y_test.csv')

# %% [markdown]
# ### Data Preprocess

# %% [markdown]
# distinguish numerical and categorical variable since it will have a different approach of preprocessing

# %%
def get_data_by_types(X_train, X_test):
    X_train_num, X_train_cat = X_train[num_columns], X_train[cat_columns]
    X_test_num, X_test_cat = X_test[num_columns], X_test[cat_columns]
    return X_train_num, X_train_cat, X_test_num, X_test_cat

# %%
X_train_num, X_train_cat, X_test_num, X_test_cat = get_data_by_types(X_train, X_test)

# %% [markdown]
# #### categorical variable

# %%
data['Saving accounts'].value_counts()
# Out:
# little        603
# moderate      103
# quite rich     63
# rich           48
# Name: Saving accounts, dtype: int64

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(strategy="constant", fill_value="missing")
imp.fit(X_train_cat)
# Out:
# SimpleImputer(fill_value='missing', strategy='constant')

# %%
X_train_cat = imp.transform(X_train_cat)
X_test_cat = imp.transform(X_test_cat)

# %% [markdown]
# Check missing value

# %%
pd.DataFrame(X_train_cat, columns=cat_columns).isnull().sum()
# Out:
# Sex                 0
# Housing             0
# Saving accounts     0
# Checking account    0
# Purpose             0
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop='first')
ohe.fit(X_train_cat)

X_train_cat = ohe.transform(X_train_cat).toarray()
X_test_cat = ohe.transform(X_test_cat).toarray()

# %%
X_train_cat = pd.DataFrame(X_train_cat, columns=ohe.get_feature_names(cat_columns), index=X_train.index)
X_test_cat = pd.DataFrame(X_test_cat, columns=ohe.get_feature_names(cat_columns), index=X_test.index)

# %%
# Create a function to preprocess categorical variable
def preprocess_categorical(X_train_cat, X_test_cat):
    imp = SimpleImputer(strategy="constant", fill_value="missing")
    ohe = OneHotEncoder(drop="first")
    
    imp.fit(X_train_cat)
    
    X_train_cat = imp.transform(X_train_cat)
    X_test_cat = imp.transform(X_test_cat)
    
    ohe.fit(X_train_cat)
    
    X_train_cat = ohe.transform(X_train_cat).toarray()
    X_test_cat = ohe.transform(X_test_cat).toarray()
    
    X_train_cat = pd.DataFrame(X_train_cat, columns=ohe.get_feature_names(cat_columns), index=X_train.index)
    X_test_cat = pd.DataFrame(X_test_cat, columns=ohe.get_feature_names(cat_columns), index=X_test.index)

    return X_train_cat, X_test_cat

# %%
X_train_num, X_train_cat, X_test_num, X_test_cat = get_data_by_types(X_train, X_test)
X_train_cat, X_test_cat = preprocess_categorical(X_train_cat, X_test_cat)

# %% [markdown]
# #### Numerical Variable

# %%
# from sklearn.preprocessing import StandardScaler

# sc = StandardScaler()
# sc.fit(X_train.loc[:, num_columns])

# %%
# X_train_num = sc.transform(X_train[num_columns])
# X_test_num = sc.transform(X_test[num_columns])

# %%
# X_train_num

# %%
X_train_trans = X_train_num.join(X_train_cat)
X_test_trans = X_test_num.join(X_test_cat)

# %%
X_train_trans.head()
# Out:
#      Age  Job  Credit amount  Duration  Sex_male  Housing_own  Housing_rent  \
# 10    25    2           1295        12       0.0          0.0           1.0
# 82    24    1           1568        18       0.0          0.0           1.0
# 827   36    2           4165        18       1.0          1.0           0.0
# 410   20    2           1967        24       0.0          1.0           0.0
# 48    39    1           7228        11       1.0          1.0           0.0
#
#      Saving accounts_missing  Saving accounts_moderate  \
# 10                       0.0                       0.0
# 82                       0.0                       1.0
# 827                      0.0                       0.0
# 410                      0.0                       0.0
# 48                       0.0                       0.0
#
#      Saving accounts_quite rich  Saving accounts_rich  \
# 10                          0.0                   0.0
# 82                          0.0                   0.0
# 827                         0.0                   0.0
# 410                         0.0                   0.0
# 48                          0.0                   0.0
#
#      Checking account_missing  Checking account_moderate  \
# 10                        0.0                        1.0
# 82                        1.0                        0.0
# 827                       1.0                        0.0
# 410                       0.0                        1.0
# 48                        1.0                        0.0
#
#      Checking account_rich  Purpose_car  Purpose_domestic appliances  \
# 10                     0.0          1.0                          0.0
# 82                     0.0          0.0                          0.0
# 827                    0.0          0.0                          0.0
# 410                    0.0          0.0                          0.0
# 48                     0.0          1.0                          0.0
#
#      Purpose_education  Purpose_furniture/equipment  Purpose_radio/TV  \
# 10                 0.0                          0.0               0.0
# 82                 0.0                          0.0               0.0
# 827                0.0                          0.0               0.0
# 410                0.0                          0.0               1.0
# 48                 0.0                          0.0               0.0
#
#      Purpose_repairs  Purpose_vacation/others
# 10               0.0                      0.0
# 82               0.0                      0.0
# 827              0.0                      0.0
# 410              0.0                      0.0
# 48               0.0                      0.0

# %%
plot_correlation(X_train_trans)

# %% [markdown]
# ### Train Model

# %%
from sklearn.linear_model import LogisticRegression  
from sklearn.metrics import roc_auc_score

lr = LogisticRegression(random_state=SEED, max_iter=1000)
lr.fit(X_train_trans, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
yhat_train = lr.predict_proba(X_train_trans)[:, 1]
yhat_test = lr.predict_proba(X_test_trans)[:, 1]

# %% [markdown]
# # Base model

# %%
print("ROC-AUC Score Train:", roc_auc_score(y_train, yhat_train))
print("ROC-AUC Score Test:", roc_auc_score(y_test, yhat_test))
# Out:
# ROC-AUC Score Train: 0.7766861030126336
# ROC-AUC Score Test: 0.7573544973544974

# %%
# https://stackoverflow.com/questions/28719067/roc-curve-and-cut-off-point-python
def get_optimal_cutoff(tpr, fpr, thresholds):
    i = np.arange(len(tpr)) # index for df
    roc = pd.DataFrame({
        'fpr' : pd.Series(fpr, index=i),
        'tpr' : pd.Series(tpr, index = i), 
        '1-fpr' : pd.Series(1-fpr, index = i), 
        'tf' : pd.Series(tpr - (1-fpr), index = i), 
        'thresholds' : pd.Series(thresholds, index = i)})
    
    print(roc.iloc[[(roc.tf-0).abs().argmin()]])

    # Plot tpr vs 1-fpr
    fig, ax = plt.subplots()
    _ = plt.plot(roc['tpr'])
    _ = plt.plot(roc['1-fpr'], color = 'red')
    _ = plt.xlabel('1-False Positive Rate')
    _ = plt.ylabel('True Positive Rate')
    _ = plt.title('Receiver operating characteristic')
    _ = ax.set_xticklabels([])
    
    
def plot_roc_auc(tpr, fpr, labels):
    
    if (isinstance(tpr, (list, np.array)) and isinstance(fpr, (list, np.array))):
        
        nlist = len(tpr)
        
        if all(len(val) == nlist for val in [tpr, fpr, labels]):
            pass
        else:
            raise ValueError('length of parameter should be the same')
               
        fig, ax = plt.subplots(figsize=(8, 6.5))
        _ = sns.despine(ax=ax)
        _ = ax.plot([0, 1], [0, 1], color='navy', linestyle='--')
        _ = ax.set_xlim([0.0, 1.0])
        _ = ax.set_ylim([0.0, 1.05])
        _ = ax.set_xlabel('False Positive Rate')
        _ = ax.set_ylabel('True Positive Rate')
        _ = ax.set_title('Receiver operating characteristic example')
        
        for i in range(nlist):
        
            roc_auc = auc(fpr[i], tpr[i])
            _ = ax.plot(
                fpr[i], 
                tpr[i], 
                label=f'ROC curve {labels[i]} (area = {roc_auc: 0.2f}'
            )
        
        _ = fig.legend(loc="right")
        
    else:
        roc_auc = auc(fpr, tpr)
        
        fig, ax = plt.subplots(figsize=(8, 6.5))
        _ = sns.despine(ax=ax)
        _ = ax.plot([0, 1], [0, 1], color='navy', linestyle='--')
        _ = ax.set_xlim([0.0, 1.0])
        _ = ax.set_ylim([0.0, 1.05])
        _ = ax.set_xlabel('False Positive Rate')
        _ = ax.set_ylabel('True Positive Rate')
        _ = ax.set_title('Receiver operating characteristic example')
        _ = ax.plot(
            fpr, 
            tpr, 
            label=f'ROC curve {labels} (area = {roc_auc: 0.2f}'
        )
        
    _ = fig.legend(loc="right")

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report

fpr_train, tpr_train, thresholds_train =roc_curve(y_train, 
                                                  yhat_train)
fpr_test, tpr_test, thresholds_test =roc_curve(y_test, 
                                               yhat_test)

roc_auc_train = auc(fpr_train, tpr_train)
roc_auc_test = auc(fpr_test, tpr_test)

print("ROC-AUC TRAIN", roc_auc_train)
print("ROC-AUC TEST", roc_auc_test)
# Out:
# ROC-AUC TRAIN 0.7766861030126336
# ROC-AUC TEST 0.7573544973544974

# %%
tpr = tpr_test
fpr = fpr_test

thresholds = thresholds_test
get_optimal_cutoff(tpr, fpr, thresholds)
# Out:
#          fpr       tpr     1-fpr        tf  thresholds
# 59  0.295238  0.677778  0.704762 -0.026984    0.331209

# %%
threshold = 0.5

y_pred_train = np.where(yhat_train > 0.276966, 1, 0)
y_pred_test = np.where(yhat_test> 0.276966, 1, 0)

print(classification_report(y_test, 
                            y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.65      0.74       210
#            1       0.48      0.74      0.58        90
#
#     accuracy                           0.68       300
#    macro avg       0.67      0.70      0.66       300
# weighted avg       0.74      0.68      0.69       300

# %%
# threshold = 0.3312090

# y_pred_train = np.where(yhat_train > threshold, 1, 0)
# y_pred_test = np.where(yhat_test> threshold, 1, 0)

# print(classification_report(y_test, 
#                             y_pred_test))

# %% [markdown]
# ## Model Validation: Cross Validation
#
# In k-fold cross-validation, we randomly split the training dataset into k folds without replacement, where k — 1 folds are used for the model training, and one fold is used for performance evaluation. This procedure is repeated k times so that we obtain k models and performance estimates.
# <img src='Capture3.png'>

# %%
#Running K-fold CV
from sklearn.model_selection import KFold

#Defining Kfold
kfold = KFold(n_splits=4, shuffle=True, random_state=SEED).split(X_train_trans, y_train)

#Defining the model
lr = LogisticRegression(random_state=SEED, C=5, max_iter=1000) # try to change C

#Initialize empty list for the scores
scores = []

#Loop the kfold
for k, (train, test) in enumerate(kfold):
    lr.fit(X_train_trans.iloc[train], y_train.iloc[train])
    
    yhat = lr.predict_proba(X_train_trans.iloc[test])[:, 1]
    score = roc_auc_score(y_train.iloc[test], yhat)
    scores.append(score)
    print('Fold: %2d, Class dist.: %s, Acc: %.3f' % (k+1,np.bincount(y_train.iloc[train]), score))
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Class dist.: [367 158], Acc: 0.723
# Fold:  2, Class dist.: [372 153], Acc: 0.723
# Fold:  3, Class dist.: [367 158], Acc: 0.787
# Fold:  4, Class dist.: [364 161], Acc: 0.771
# CV accuracy: 0.751 +/- 0.028

# %%
#Running K-fold CV
from sklearn.model_selection import StratifiedKFold

#Defining Kfold
skfold = StratifiedKFold(n_splits=4, shuffle=True, random_state=SEED).split(X_train_trans, y_train)

#Defining the model
lr = LogisticRegression(random_state=SEED, max_iter=1000)

#Initialize empty list for the scores
scores = []

#Loop the kfold
for k, (train, test) in enumerate(skfold):
    lr.fit(X_train_trans.iloc[train], y_train.iloc[train])
    
    yhat = lr.predict_proba(X_train_trans.iloc[test])[:, 1]
    score = roc_auc_score(y_train.iloc[test], yhat)
    scores.append(score)
    print('Fold: %2d, Class dist.: %s, Acc: %.3f' % (k+1,np.bincount(y_train.iloc[train]), score))
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Class dist.: [368 157], Acc: 0.734
# Fold:  2, Class dist.: [368 157], Acc: 0.752
# Fold:  3, Class dist.: [367 158], Acc: 0.660
# Fold:  4, Class dist.: [367 158], Acc: 0.740
# CV accuracy: 0.722 +/- 0.036

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Simple Hyperparameter Tuning - GridSearchCV

# %%
from sklearn.utils.fixes import loguniform
from sklearn.linear_model import LogisticRegression  
from sklearn.model_selection import GridSearchCV

lr = LogisticRegression(random_state=SEED)

param_space = {
    "C": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "max_iter": [1000],
    "random_state": [SEED]
}

clf = GridSearchCV(lr, 
                   param_space, 
                   scoring='roc_auc', 
                   cv=4, 
                   refit=True)

# %%
clf.fit(X_train_trans, y_train)
# Out:
# GridSearchCV(cv=4, estimator=LogisticRegression(random_state=42),
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'max_iter': [1000], 'random_state': [42]},
#              scoring='roc_auc')

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report

fpr_train, tpr_train, thresholds_train =roc_curve(y_train, 
                                                  yhat_train)
fpr_test, tpr_test, thresholds_test =roc_curve(y_test, 
                                               yhat_test)

roc_auc_train = auc(fpr_train, tpr_train)
roc_auc_test = auc(fpr_test, tpr_test)

print("ROC-AUC TRAIN", roc_auc_train)
print("ROC-AUC TEST", roc_auc_test)
# Out:
# ROC-AUC TRAIN 0.7766861030126336
# ROC-AUC TEST 0.7573544973544974

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### Implement data preprocess to pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


cat_pipe = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="constant", fill_value="missing")),
    ('ohe', OneHotEncoder(drop="first"))
])

num_pipe = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocess = ColumnTransformer(
    transformers=[
    ('cat', cat_pipe, cat_columns),
    ('num', num_pipe, num_columns)
], remainder='passthrough')

preprocess.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first'))]),
#                                  ['Sex', 'Housing', 'Saving accounts',
#                                   'Checking account', 'Purpose']),
#                                 ('num',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['Age', 'Job', 'Credit amount', 'Duration'])])

# %%
ohe_columns = preprocess.named_transformers_['cat'].named_steps['ohe'].get_feature_names(cat_columns)

final_features = []
final_features.extend(ohe_columns)
final_features.extend(num_columns)

# %%
X_train_trans = pd.DataFrame(preprocess.transform(X_train), columns=final_features)
X_test_trans = pd.DataFrame(preprocess.transform(X_test), columns=final_features)

# %%
lr = LogisticRegression(random_state=SEED, max_iter=1000)
lr.fit(X_train_trans, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
yhat_train = lr.predict_proba(X_train_trans)[:, 1]
yhat_test = lr.predict_proba(X_test_trans)[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report

fpr_train, tpr_train, thresholds_train =roc_curve(y_train, 
                                                  yhat_train)
fpr_test, tpr_test, thresholds_test =roc_curve(y_test, 
                                               yhat_test)

roc_auc_train = auc(fpr_train, tpr_train)
roc_auc_test = auc(fpr_test, tpr_test)

print("ROC-AUC TRAIN", roc_auc_train)
print("ROC-AUC TEST", roc_auc_test)
# Out:
# ROC-AUC TRAIN 0.7774246841593779
# ROC-AUC TEST 0.7583597883597885

# %% [markdown]
# ### Full Pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


cat_pipe = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="constant", fill_value="missing")),
    ('ohe', OneHotEncoder(drop="first"))
])

num_pipe = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocess = ColumnTransformer(transformers=[
    ('cat', cat_pipe, cat_columns),
    ('num', num_pipe, num_columns)
], remainder='passthrough')


full_pipe = Pipeline(steps=[
    ('preprocess', preprocess),
    ('model', LogisticRegression(random_state=SEED, max_iter=1000))
])

# %%
full_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first'))]),
#                                                   ['Sex', 'Housing',
#                                                    'Saving accounts',
#                                                    'Checking account',
#                                                    'Purpose']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Job',
#                                                    'Credit amount',
#                                                    'Duration'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report


yhat_train = full_pipe.predict_proba(X_train)[:, 1]
yhat_test = full_pipe.predict_proba(X_test)[:, 1]

fpr_train, tpr_train, thresholds_train =roc_curve(y_train, 
                                                  yhat_train)
fpr_test, tpr_test, thresholds_test =roc_curve(y_test, 
                                               yhat_test)

roc_auc_train = auc(fpr_train, tpr_train)
roc_auc_test = auc(fpr_test, tpr_test)

print("ROC-AUC TRAIN", roc_auc_train)
print("ROC-AUC TEST", roc_auc_test)
# Out:
# ROC-AUC TRAIN 0.7774246841593779
# ROC-AUC TEST 0.7583597883597885

# %% [markdown]
# ### Hyperparameter Tuning with Pipeline - GridSearchCV

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


cat_pipe = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="constant", fill_value="missing")),
    ('ohe', OneHotEncoder(drop="first"))
])

num_pipe = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocess = ColumnTransformer(transformers=[
    ('cat', cat_pipe, cat_columns),
    ('num', num_pipe, num_columns)
], remainder='passthrough')


full_pipe = Pipeline(steps=[
    ('preprocess', preprocess),
    ('model', LogisticRegression(random_state=SEED, max_iter=1000))
])

# %%
param_space = {
    "model__C": [0.0001, 0.001, 0.01, 0.1, 2, 1, 3, 4, 5, 10, 100, 1000],
    "model__max_iter": [1000],
    "model__random_state": [SEED]
}

clf = GridSearchCV(full_pipe, 
                   param_space, 
                   scoring='roc_auc', 
                   cv=5, 
                   refit=True)

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='missing',
#                                                                                                         strategy='constant')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first'))]),
#                                                                          ['Sex',
#                                                                           'Housing',
#                                                                           'Saving '
#                                                                           'accounts',
#                                                                           'Checking '
#                                                                           'account',
#                                                                           'Purpose']),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['Age',
#                                                                           'Job',
#                                                                           'Credit '
#                                                                           'amount',
#                                                                           'Duration'])])),
#                                        ('model',
#                                         LogisticRegression(max_iter=1000,
#                                                            random_state=42))]),
#              param_grid={'model__C': [0.0001, 0.001, 0.01, 0.1, 2, 1, 3, 4, 5,
#                                       10, 100, 1000],
#                          'model__max_iter': [1000],
#                          'model__random_state': [42]},
#              scoring='roc_auc')

# %%
clf.best_params_
# Out:
# {'model__C': 1, 'model__max_iter': 1000, 'model__random_state': 42}

# %%
clf.best_estimator_.named_steps['model']
# Out:
# LogisticRegression(C=1, max_iter=1000, random_state=42)

# %%
yhat_train = clf.predict_proba(X_train)[:, 1]
yhat_test = clf.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report

fpr_train, tpr_train, thresholds_train =roc_curve(y_train, 
                                                  yhat_train)
fpr_test, tpr_test, thresholds_test =roc_curve(y_test, 
                                               yhat_test)

roc_auc_train = auc(fpr_train, tpr_train)
roc_auc_test = auc(fpr_test, tpr_test)

print("ROC-AUC TRAIN", roc_auc_train)
print("ROC-AUC TEST", roc_auc_test)
# Out:
# ROC-AUC TRAIN 0.7774246841593779
# ROC-AUC TEST 0.7583597883597885

# %%
tpr = tpr_test
fpr = fpr_test

thresholds = thresholds_test
get_optimal_cutoff(tpr, fpr, thresholds)
# Out:
#          fpr       tpr     1-fpr        tf  thresholds
# 58  0.295238  0.711111  0.704762  0.006349    0.313929

# %%
threshold = 0.5

y_pred_train = np.where(yhat_train > threshold, 1, 0)
y_pred_test = np.where(yhat_test> threshold, 1, 0)

print(classification_report(y_test, 
                            y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       210
#            1       0.64      0.39      0.48        90
#
#     accuracy                           0.75       300
#    macro avg       0.71      0.65      0.66       300
# weighted avg       0.73      0.75      0.73       300

# %%
threshold = 0.313929

y_pred_train = np.where(yhat_train > threshold, 1, 0)
y_pred_test = np.where(yhat_test> threshold, 1, 0)

print(classification_report(y_test, 
                            y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77       210
#            1       0.51      0.71      0.59        90
#
#     accuracy                           0.71       300
#    macro avg       0.68      0.71      0.68       300
# weighted avg       0.75      0.71      0.72       300

# %%
X_train.loc[:, 'Risk'] = y_train
X_train.loc[:, 'score_proba'] = yhat_train
X_test.loc[:, 'Risk'] = y_test
X_test.loc[:, 'score_proba'] = yhat_test
# Out:
# /Volumes/BOOTCAMP/materi-data-science/model-selection/.venv/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
X_test.head()
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 115   47    male    2     own             NaN              NaN           3578
# 346   23    male    2     own          little         moderate            882
# 328   31    male    2     own          little             rich           4473
# 974   33  female    2     own          little              NaN           2831
# 587   21    male    1     own          little           little           1289
#
#      Duration              Purpose  Risk  score_proba
# 115        48             radio/TV     0     0.103430
# 346        13             radio/TV     0     0.271002
# 328        36             radio/TV     0     0.376129
# 974        30             radio/TV     0     0.195884
# 587        12  furniture/equipment     0     0.363718

# %% [markdown]
# ## Save Your Model

# %%
import pickle 


MODELNAME = 'M-LR-1.0.0.pkl'
PREPROCESSNAME = 'FE-SC-IMP-OHE-1.0.0.pkl'

final_model = clf.best_estimator_.named_steps['model']
final_pipe = clf.best_estimator_.named_steps['preprocess']

with open(MODELNAME, 'wb') as f: # save model
    pickle.dump(final_model, f)
    
with open(PREPROCESSNAME, 'wb') as f: # save pipeline
    pickle.dump(final_pipe, f)

# %%
X_train.to_csv('train.csv')
X_test.to_csv('test.csv')

# %%
pd.DataFrame(clf.cv_results_)

# %% [markdown]
# ## **[Optional] feature selection**

# %%
# from sklearn.feature_selection import RFE

# lr = LogisticRegression(random_state=SEED)
# rfe = RFE(lr, n_features_to_select=7)
# rfe.fit(X_train_sc, y_train)

# %%
X_train_rfe = rfe.transform(X_train_sc)
X_test_rfe = rfe.transform(X_test_sc)

# %%
from sklearn.feature_selection import RFE

lr = LogisticRegression(random_state=SEED)
lr.fit(X_train_rfe, y_train)

# %%
yhat_train = lr.predict_proba(X_train_rfe)[:, 1]
yhat_test = lr.predict_proba(X_test_rfe)[:, 1]

print("ROC-AUC Score Train:", roc_auc_score(y_train, yhat_train))
print("ROC-AUC Score Test:", roc_auc_score(y_test, yhat_test))

# %% [markdown]
# ## Full implementation (preproecss + feature selection + algorithm selection)

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# %%
sc = StandardScaler()
lr = LogisticRegression(random_state=SEED)
rf = RandomForestClassifier(n_estimators=10, random_state=SEED)
rfe = RFE(lr)

pipe = Pipeline([('scaler', StandardScaler()),
                 ('selector', rfe),
                 ('classifier', LogisticRegression(random_state=True))])

# %%
search_space = [
                {'selector': [RFE(estimator=lr)],
                 'selector__n_features_to_select': [6, 7, 8],
                 'classifier': [LogisticRegression(solver='lbfgs', random_state=SEED)],
                 'classifier__C': [0.001, 0.01, 0.1, 1.0, 10, 1000]},
                {'selector': [RFE(estimator=rf)],
                 'selector__n_features_to_select': [6, 7, 8],
                 'classifier': [RandomForestClassifier(random_state=SEED)],
                 'classifier__n_estimators': [5, 10, 15, 20],
                 'classifier__max_depth': [2, 3, 4]}
]

# %%
clf = GridSearchCV(pipe, search_space, cv=5, scoring='roc_auc', verbose=0, return_train_score=True)
clf.fit(X_train[num_columns], y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('selector',
#                                         RFE(estimator=LogisticRegression(random_state=42))),
#                                        ('classifier',
#                                         LogisticRegression(random_state=True))]),
#              param_grid=[{'classifier': [LogisticRegression(C=0.001,
#                                                             random_state=42)],
#                           'classifier__C': [0.001, 0.01, 0.1, 1.0, 10, 1000],
#                           'selector': [RFE(estimator=LogisticRegressi...
#                           'selector__n_features_to_select': [6, 7, 8]},
#                          {'classifier': [RandomForestClassifier(max_depth=3,
#                                                                 n_estimators=10,
#                                                                 random_state=42)],
#                           'classifier__max_depth': [2, 3, 4],
#                           'classifier__n_estimators': [5, 10, 15, 20],
#                           'selector': [RFE(estimator=RandomForestClassifier(n_estimators=10,
#                                                                             random_state=42),
#                                            n_features_to_select=6)],
#                           'selector__n_features_to_select': [6, 7, 8]}],
#              return_train_score=True, scoring='roc_auc')

# %%
clf.best_params_
# Out:
# {'classifier': RandomForestClassifier(max_depth=3, n_estimators=10, random_state=42),
#  'classifier__max_depth': 3,
#  'classifier__n_estimators': 10,
#  'selector': RFE(estimator=RandomForestClassifier(n_estimators=10, random_state=42),
#      n_features_to_select=6),
#  'selector__n_features_to_select': 6}

# %%
clf.best_score_
# Out:
# 0.6143343051506316

# %%
yhat_train = clf.predict_proba(X_train[num_columns])[:, 1]
yhat_test = clf.predict_proba(X_test[num_columns])[:, 1]

print("ROC-AUC Score Train:", roc_auc_score(y_train, yhat_train))
print("ROC-AUC Score Test:", roc_auc_score(y_test, yhat_test))
# Out:
# ROC-AUC Score Train: 0.6945189504373178
# ROC-AUC Score Test: 0.695

# %%
log_result = pd.DataFrame(clf.cv_results_)

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
# log_result.to_csv('log-model-development.csv')
log_result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.075700      0.051543         0.034856        0.026794
# 1        0.022233      0.003671         0.005755        0.001516
# 2        0.025179      0.007284         0.006458        0.002970
# 3        0.023406      0.004525         0.005674        0.002721
# 4        0.042923      0.029087         0.008331        0.004139
# 5        0.023822      0.005427         0.003888        0.000603
# 6        0.027856      0.005122         0.009022        0.005595
# 7        0.024945      0.005165         0.005467        0.001638
# 8        0.022853      0.003851         0.005990        0.000524
# 9        0.037281      0.015140         0.009584        0.007869
# 10       0.025159      0.006012         0.004540        0.000544
# 11       0.029120      0.003296         0.007024        0.001838
# 12       0.025125      0.005323         0.005850        0.001471
# 13       0.028046      0.007525         0.005232        0.001476
# 14       0.032287      0.003301         0.005387        0.002047
# 15       0.030948      0.002696         0.006254        0.002386
# 16       0.030970      0.003883         0.008222        0.002306
# 17       0.036068      0.007137         0.007746        0.004223
# 18       0.066328      0.012949         0.005987        0.000722
# 19       0.056863      0.004500         0.004890        0.000854
# 20       0.055148      0.003362         0.008286        0.002521
# 21       0.064503      0.004483         0.006719        0.001096
# 22       0.066778      0.006933         0.007719        0.002756
# 23       0.064743      0.005745         0.006669        0.000844
# 24       0.083110      0.012329         0.011355        0.001779
# 25       0.086752      0.011410         0.008766        0.001232
# 26       0.077193      0.004542         0.009558        0.002622
# 27       0.087545      0.006337         0.009396        0.001234
# 28       0.097786      0.010036         0.009598        0.002321
# 29       0.089940      0.002873         0.010462        0.002768
# 30       0.050861      0.003472         0.007526        0.002564
# 31       0.057633      0.006346         0.006928        0.002534
# 32       0.057599      0.010384         0.005693        0.001089
# 33       0.074674      0.007047         0.007650        0.000963
# 34       0.072161      0.007494         0.007609        0.002531
# 35       0.072749      0.003803         0.009524        0.003775
# 36       0.093391      0.007534         0.007795        0.001750
# 37       0.078324      0.002627         0.008141        0.001625
# 38       0.079874      0.004679         0.009620        0.002642
# 39       0.090280      0.008269         0.009257        0.001502
# 40       0.092592      0.007482         0.009923        0.002157
# 41       0.104334      0.022823         0.010746        0.002383
# 42       0.070309      0.007250         0.007494        0.000550
# 43       0.091611      0.013441         0.010294        0.002923
# 44       0.091803      0.008563         0.013254        0.004768
# 45       0.108569      0.008380         0.011265        0.002171
# 46       0.104430      0.017844         0.013992        0.004729
# 47       0.088497      0.009600         0.010872        0.006663
# 48       0.106613      0.009918         0.009629        0.002661
# 49       0.118162      0.017818         0.011853        0.002331
# 50       0.138138      0.039954         0.011313        0.001252
# 51       0.141241      0.014256         0.011809        0.003299
# 52       0.123268      0.006070         0.010421        0.001397
# 53       0.130171      0.007694         0.014930        0.004551
#
#                                      param_classifier param_classifier__C  \
# 0        LogisticRegression(C=0.001, random_state=42)               0.001
# 1        LogisticRegression(C=0.001, random_state=42)               0.001
# 2        LogisticRegression(C=0.001, random_state=42)               0.001
# 3        LogisticRegression(C=0.001, random_state=42)                0.01
# 4        LogisticRegression(C=0.001, random_state=42)                0.01
# 5        LogisticRegression(C=0.001, random_state=42)                0.01
# 6        LogisticRegression(C=0.001, random_state=42)                 0.1
# 7        LogisticRegression(C=0.001, random_state=42)                 0.1
# 8        LogisticRegression(C=0.001, random_state=42)                 0.1
# 9        LogisticRegression(C=0.001, random_state=42)                 1.0
# 10       LogisticRegression(C=0.001, random_state=42)                 1.0
# 11       LogisticRegression(C=0.001, random_state=42)                 1.0
# 12       LogisticRegression(C=0.001, random_state=42)                  10
# 13       LogisticRegression(C=0.001, random_state=42)                  10
# 14       LogisticRegression(C=0.001, random_state=42)                  10
# 15       LogisticRegression(C=0.001, random_state=42)                1000
# 16       LogisticRegression(C=0.001, random_state=42)                1000
# 17       LogisticRegression(C=0.001, random_state=42)                1000
# 18  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 19  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 20  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 21  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 22  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 23  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 24  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 25  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 26  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 27  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 28  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 29  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 30  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 31  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 32  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 33  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 34  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 35  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 36  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 37  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 38  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 39  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 40  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 41  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 42  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 43  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 44  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 45  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 46  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 47  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 48  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 49  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 50  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 51  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 52  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
# 53  RandomForestClassifier(max_depth=3, n_estimato...                 NaN
#
#                                        param_selector  \
# 0   RFE(estimator=LogisticRegression(random_state=...
# 1   RFE(estimator=LogisticRegression(random_state=...
# 2   RFE(estimator=LogisticRegression(random_state=...
# 3   RFE(estimator=LogisticRegression(random_state=...
# 4   RFE(estimator=LogisticRegression(random_state=...
# 5   RFE(estimator=LogisticRegression(random_state=...
# 6   RFE(estimator=LogisticRegression(random_state=...
# 7   RFE(estimator=LogisticRegression(random_state=...
# 8   RFE(estimator=LogisticRegression(random_state=...
# 9   RFE(estimator=LogisticRegression(random_state=...
# 10  RFE(estimator=LogisticRegression(random_state=...
# 11  RFE(estimator=LogisticRegression(random_state=...
# 12  RFE(estimator=LogisticRegression(random_state=...
# 13  RFE(estimator=LogisticRegression(random_state=...
# 14  RFE(estimator=LogisticRegression(random_state=...
# 15  RFE(estimator=LogisticRegression(random_state=...
# 16  RFE(estimator=LogisticRegression(random_state=...
# 17  RFE(estimator=LogisticRegression(random_state=...
# 18  RFE(estimator=RandomForestClassifier(n_estimat...
# 19  RFE(estimator=RandomForestClassifier(n_estimat...
# 20  RFE(estimator=RandomForestClassifier(n_estimat...
# 21  RFE(estimator=RandomForestClassifier(n_estimat...
# 22  RFE(estimator=RandomForestClassifier(n_estimat...
# 23  RFE(estimator=RandomForestClassifier(n_estimat...
# 24  RFE(estimator=RandomForestClassifier(n_estimat...
# 25  RFE(estimator=RandomForestClassifier(n_estimat...
# 26  RFE(estimator=RandomForestClassifier(n_estimat...
# 27  RFE(estimator=RandomForestClassifier(n_estimat...
# 28  RFE(estimator=RandomForestClassifier(n_estimat...
# 29  RFE(estimator=RandomForestClassifier(n_estimat...
# 30  RFE(estimator=RandomForestClassifier(n_estimat...
# 31  RFE(estimator=RandomForestClassifier(n_estimat...
# 32  RFE(estimator=RandomForestClassifier(n_estimat...
# 33  RFE(estimator=RandomForestClassifier(n_estimat...
# 34  RFE(estimator=RandomForestClassifier(n_estimat...
# 35  RFE(estimator=RandomForestClassifier(n_estimat...
# 36  RFE(estimator=RandomForestClassifier(n_estimat...
# 37  RFE(estimator=RandomForestClassifier(n_estimat...
# 38  RFE(estimator=RandomForestClassifier(n_estimat...
# 39  RFE(estimator=RandomForestClassifier(n_estimat...
# 40  RFE(estimator=RandomForestClassifier(n_estimat...
# 41  RFE(estimator=RandomForestClassifier(n_estimat...
# 42  RFE(estimator=RandomForestClassifier(n_estimat...
# 43  RFE(estimator=RandomForestClassifier(n_estimat...
# 44  RFE(estimator=RandomForestClassifier(n_estimat...
# 45  RFE(estimator=RandomForestClassifier(n_estimat...
# 46  RFE(estimator=RandomForestClassifier(n_estimat...
# 47  RFE(estimator=RandomForestClassifier(n_estimat...
# 48  RFE(estimator=RandomForestClassifier(n_estimat...
# 49  RFE(estimator=RandomForestClassifier(n_estimat...
# 50  RFE(estimator=RandomForestClassifier(n_estimat...
# 51  RFE(estimator=RandomForestClassifier(n_estimat...
# 52  RFE(estimator=RandomForestClassifier(n_estimat...
# 53  RFE(estimator=RandomForestClassifier(n_estimat...
#
#    param_selector__n_features_to_select param_classifier__max_depth  \
# 0                                     6                         NaN
# 1                                     7                         NaN
# 2                                     8                         NaN
# 3                                     6                         NaN
# 4                                     7                         NaN
# 5                                     8                         NaN
# 6                                     6                         NaN
# 7                                     7                         NaN
# 8                                     8                         NaN
# 9                                     6                         NaN
# 10                                    7                         NaN
# 11                                    8                         NaN
# 12                                    6                         NaN
# 13                                    7                         NaN
# 14                                    8                         NaN
# 15                                    6                         NaN
# 16                                    7                         NaN
# 17                                    8                         NaN
# 18                                    6                           2
# 19                                    7                           2
# 20                                    8                           2
# 21                                    6                           2
# 22                                    7                           2
# 23                                    8                           2
# 24                                    6                           2
# 25                                    7                           2
# 26                                    8                           2
# 27                                    6                           2
# 28                                    7                           2
# 29                                    8                           2
# 30                                    6                           3
# 31                                    7                           3
# 32                                    8                           3
# 33                                    6                           3
# 34                                    7                           3
# 35                                    8                           3
# 36                                    6                           3
# 37                                    7                           3
# 38                                    8                           3
# 39                                    6                           3
# 40                                    7                           3
# 41                                    8                           3
# 42                                    6                           4
# 43                                    7                           4
# 44                                    8                           4
# 45                                    6                           4
# 46                                    7                           4
# 47                                    8                           4
# 48                                    6                           4
# 49                                    7                           4
# 50                                    8                           4
# 51                                    6                           4
# 52                                    7                           4
# 53                                    8                           4
#
#    param_classifier__n_estimators  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                              5
# 19                              5
# 20                              5
# 21                             10
# 22                             10
# 23                             10
# 24                             15
# 25                             15
# 26                             15
# 27                             20
# 28                             20
# 29                             20
# 30                              5
# 31                              5
# 32                              5
# 33                             10
# 34                             10
# 35                             10
# 36                             15
# 37                             15
# 38                             15
# 39                             20
# 40                             20
# 41                             20
# 42                              5
# 43                              5
# 44                              5
# 45                             10
# 46                             10
# 47                             10
# 48                             15
# 49                             15
# 50                             15
# 51                             20
# 52                             20
# 53                             20
#
#                                                params  split0_test_score  \
# 0   {'classifier': LogisticRegression(C=0.001, ran...           0.656220
# 1   {'classifier': LogisticRegression(C=0.001, ran...           0.656220
# 2   {'classifier': LogisticRegression(C=0.001, ran...           0.656220
# 3   {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 4   {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 5   {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 6   {'classifier': LogisticRegression(C=0.001, ran...           0.662293
# 7   {'classifier': LogisticRegression(C=0.001, ran...           0.662293
# 8   {'classifier': LogisticRegression(C=0.001, ran...           0.662293
# 9   {'classifier': LogisticRegression(C=0.001, ran...           0.662536
# 10  {'classifier': LogisticRegression(C=0.001, ran...           0.662536
# 11  {'classifier': LogisticRegression(C=0.001, ran...           0.662536
# 12  {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 13  {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 14  {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 15  {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 16  {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 17  {'classifier': LogisticRegression(C=0.001, ran...           0.661808
# 18  {'classifier': RandomForestClassifier(max_dept...           0.496477
# 19  {'classifier': RandomForestClassifier(max_dept...           0.496477
# 20  {'classifier': RandomForestClassifier(max_dept...           0.496477
# 21  {'classifier': RandomForestClassifier(max_dept...           0.593294
# 22  {'classifier': RandomForestClassifier(max_dept...           0.593294
# 23  {'classifier': RandomForestClassifier(max_dept...           0.593294
# 24  {'classifier': RandomForestClassifier(max_dept...           0.625486
# 25  {'classifier': RandomForestClassifier(max_dept...           0.625486
# 26  {'classifier': RandomForestClassifier(max_dept...           0.625486
# 27  {'classifier': RandomForestClassifier(max_dept...           0.637269
# 28  {'classifier': RandomForestClassifier(max_dept...           0.637269
# 29  {'classifier': RandomForestClassifier(max_dept...           0.637269
# 30  {'classifier': RandomForestClassifier(max_dept...           0.558309
# 31  {'classifier': RandomForestClassifier(max_dept...           0.558309
# 32  {'classifier': RandomForestClassifier(max_dept...           0.558309
# 33  {'classifier': RandomForestClassifier(max_dept...           0.590622
# 34  {'classifier': RandomForestClassifier(max_dept...           0.590622
# 35  {'classifier': RandomForestClassifier(max_dept...           0.590622
# 36  {'classifier': RandomForestClassifier(max_dept...           0.603377
# 37  {'classifier': RandomForestClassifier(max_dept...           0.603377
# 38  {'classifier': RandomForestClassifier(max_dept...           0.603377
# 39  {'classifier': RandomForestClassifier(max_dept...           0.593052
# 40  {'classifier': RandomForestClassifier(max_dept...           0.593052
# 41  {'classifier': RandomForestClassifier(max_dept...           0.593052
# 42  {'classifier': RandomForestClassifier(max_dept...           0.522838
# 43  {'classifier': RandomForestClassifier(max_dept...           0.522838
# 44  {'classifier': RandomForestClassifier(max_dept...           0.522838
# 45  {'classifier': RandomForestClassifier(max_dept...           0.563776
# 46  {'classifier': RandomForestClassifier(max_dept...           0.563776
# 47  {'classifier': RandomForestClassifier(max_dept...           0.563776
# 48  {'classifier': RandomForestClassifier(max_dept...           0.560982
# 49  {'classifier': RandomForestClassifier(max_dept...           0.560982
# 50  {'classifier': RandomForestClassifier(max_dept...           0.560982
# 51  {'classifier': RandomForestClassifier(max_dept...           0.555758
# 52  {'classifier': RandomForestClassifier(max_dept...           0.555758
# 53  {'classifier': RandomForestClassifier(max_dept...           0.555758
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.520894           0.620262           0.606414
# 1            0.520894           0.620262           0.606414
# 2            0.520894           0.620262           0.606414
# 3            0.527211           0.609815           0.619776
# 4            0.527211           0.609815           0.619776
# 5            0.527211           0.609815           0.619776
# 6            0.532556           0.603499           0.637026
# 7            0.532556           0.603499           0.637026
# 8            0.532556           0.603499           0.637026
# 9            0.529640           0.606171           0.640428
# 10           0.529640           0.606171           0.640428
# 11           0.529640           0.606171           0.640428
# 12           0.529155           0.607386           0.640185
# 13           0.529155           0.607386           0.640185
# 14           0.529155           0.607386           0.640185
# 15           0.528912           0.607386           0.640185
# 16           0.528912           0.607386           0.640185
# 17           0.528912           0.607386           0.640185
# 18           0.586856           0.602405           0.616497
# 19           0.586856           0.602405           0.616497
# 20           0.586856           0.602405           0.616497
# 21           0.586492           0.583576           0.622328
# 22           0.586492           0.583576           0.622328
# 23           0.586492           0.583576           0.622328
# 24           0.564869           0.580296           0.606657
# 25           0.564869           0.580296           0.606657
# 26           0.564869           0.580296           0.606657
# 27           0.560131           0.599611           0.631195
# 28           0.560131           0.599611           0.631195
# 29           0.560131           0.599611           0.631195
# 30           0.632167           0.576045           0.604470
# 31           0.632167           0.576045           0.604470
# 32           0.632167           0.576045           0.604470
# 33           0.617833           0.591715           0.646866
# 34           0.617833           0.591715           0.646866
# 35           0.617833           0.591715           0.646866
# 36           0.592930           0.587585           0.621477
# 37           0.592930           0.587585           0.621477
# 38           0.592930           0.587585           0.621477
# 39           0.584913           0.599854           0.636783
# 40           0.584913           0.599854           0.636783
# 41           0.584913           0.599854           0.636783
# 42           0.607264           0.540330           0.606050
# 43           0.607264           0.540330           0.606050
# 44           0.607264           0.540330           0.606050
# 45           0.611395           0.545068           0.634354
# 46           0.611395           0.545068           0.634354
# 47           0.611395           0.545068           0.634354
# 48           0.592444           0.565719           0.621234
# 49           0.592444           0.565719           0.621234
# 50           0.592444           0.565719           0.621234
# 51           0.587464           0.589286           0.635933
# 52           0.587464           0.589286           0.635933
# 53           0.587464           0.589286           0.635933
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0            0.629252         0.606608        0.045842               22
# 1            0.629252         0.606608        0.045842               22
# 2            0.629252         0.606608        0.045842               22
# 3            0.628766         0.609475        0.044687               19
# 4            0.628766         0.609475        0.044687               19
# 5            0.628766         0.609475        0.044687               19
# 6            0.623664         0.611808        0.043989               13
# 7            0.623664         0.611808        0.043989               13
# 8            0.623664         0.611808        0.043989               13
# 9            0.623421         0.612439        0.045406                4
# 10           0.623421         0.612439        0.045406                4
# 11           0.623421         0.612439        0.045406                4
# 12           0.622449         0.612196        0.045318                7
# 13           0.622449         0.612196        0.045318                7
# 14           0.622449         0.612196        0.045318                7
# 15           0.622206         0.612099        0.045397               10
# 16           0.622206         0.612099        0.045397               10
# 17           0.622206         0.612099        0.045397               10
# 18           0.640671         0.588581        0.049335               49
# 19           0.640671         0.588581        0.049335               49
# 20           0.640671         0.588581        0.049335               49
# 21           0.615160         0.600170        0.015655               34
# 22           0.615160         0.600170        0.015655               34
# 23           0.615160         0.600170        0.015655               34
# 24           0.596210         0.594704        0.020930               43
# 25           0.596210         0.594704        0.020930               43
# 26           0.596210         0.594704        0.020930               43
# 27           0.592444         0.604130        0.028013               31
# 28           0.592444         0.604130        0.028013               31
# 29           0.592444         0.604130        0.028013               31
# 30           0.652575         0.604713        0.034698               28
# 31           0.652575         0.604713        0.034698               28
# 32           0.652575         0.604713        0.034698               28
# 33           0.624636         0.614334        0.021216                1
# 34           0.624636         0.614334        0.021216                1
# 35           0.624636         0.614334        0.021216                1
# 36           0.619048         0.604883        0.013567               25
# 37           0.619048         0.604883        0.013567               25
# 38           0.619048         0.604883        0.013567               25
# 39           0.633746         0.609670        0.021449               16
# 40           0.633746         0.609670        0.021449               16
# 41           0.633746         0.609670        0.021449               16
# 42           0.640185         0.583333        0.044339               52
# 43           0.640185         0.583333        0.044339               52
# 44           0.640185         0.583333        0.044339               52
# 45           0.624879         0.595894        0.035141               40
# 46           0.624879         0.595894        0.035141               40
# 47           0.624879         0.595894        0.035141               40
# 48           0.607872         0.589650        0.023375               46
# 49           0.607872         0.589650        0.023375               46
# 50           0.607872         0.589650        0.023375               46
# 51           0.622328         0.598154        0.028291               37
# 52           0.622328         0.598154        0.028291               37
# 53           0.622328         0.598154        0.028291               37
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.607522            0.635477            0.620536
# 1             0.607522            0.635477            0.620536
# 2             0.607522            0.635477            0.620536
# 3             0.617590            0.643510            0.628675
# 4             0.617590            0.643510            0.628675
# 5             0.617590            0.643510            0.628675
# 6             0.623056            0.649614            0.634642
# 7             0.623056            0.649614            0.634642
# 8             0.623056            0.649614            0.634642
# 9             0.623573            0.650677            0.634840
# 10            0.623573            0.650677            0.634840
# 11            0.623573            0.650677            0.634840
# 12            0.623664            0.650692            0.634779
# 13            0.623664            0.650692            0.634779
# 14            0.623664            0.650692            0.634779
# 15            0.623679            0.650677            0.634733
# 16            0.623679            0.650677            0.634733
# 17            0.623679            0.650677            0.634733
# 18            0.684714            0.702571            0.671366
# 19            0.684714            0.702571            0.671366
# 20            0.684714            0.702571            0.671366
# 21            0.700339            0.702525            0.684691
# 22            0.700339            0.702525            0.684691
# 23            0.700339            0.702525            0.684691
# 24            0.695100            0.699025            0.691516
# 25            0.695100            0.699025            0.691516
# 26            0.695100            0.699025            0.691516
# 27            0.694804            0.702647            0.695062
# 28            0.694804            0.702647            0.695062
# 29            0.694804            0.702647            0.695062
# 30            0.735947            0.741238            0.727990
# 31            0.735947            0.741238            0.727990
# 32            0.735947            0.741238            0.727990
# 33            0.751162            0.728081            0.739166
# 34            0.751162            0.728081            0.739166
# 35            0.751162            0.728081            0.739166
# 36            0.751329            0.728795            0.744124
# 37            0.751329            0.728795            0.744124
# 38            0.751329            0.728795            0.744124
# 39            0.756590            0.736516            0.752635
# 40            0.756590            0.736516            0.752635
# 41            0.756590            0.736516            0.752635
# 42            0.755102            0.772390            0.762489
# 43            0.755102            0.772390            0.762489
# 44            0.755102            0.772390            0.762489
# 45            0.778843            0.793155            0.787035
# 46            0.778843            0.793155            0.787035
# 47            0.778843            0.793155            0.787035
# 48            0.802387            0.795197            0.793147
# 49            0.802387            0.795197            0.793147
# 50            0.802387            0.795197            0.793147
# 51            0.804634            0.797004            0.799677
# 52            0.804634            0.797004            0.799677
# 53            0.804634            0.797004            0.799677
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0             0.608828            0.618698          0.618212         0.010060
# 1             0.608828            0.618698          0.618212         0.010060
# 2             0.608828            0.618698          0.618212         0.010060
# 3             0.614690            0.625881          0.626069         0.010123
# 4             0.614690            0.625881          0.626069         0.010123
# 5             0.614690            0.625881          0.626069         0.010123
# 6             0.622434            0.630284          0.632006         0.009917
# 7             0.622434            0.630284          0.632006         0.009917
# 8             0.622434            0.630284          0.632006         0.009917
# 9             0.625364            0.631195          0.633130         0.009656
# 10            0.625364            0.631195          0.633130         0.009656
# 11            0.625364            0.631195          0.633130         0.009656
# 12            0.625729            0.631423          0.633257         0.009575
# 13            0.625729            0.631423          0.633257         0.009575
# 14            0.625729            0.631423          0.633257         0.009575
# 15            0.625744            0.631484          0.633263         0.009560
# 16            0.625744            0.631484          0.633263         0.009560
# 17            0.625744            0.631484          0.633263         0.009560
# 18            0.689330            0.665999          0.682796         0.013040
# 19            0.689330            0.665999          0.682796         0.013040
# 20            0.689330            0.665999          0.682796         0.013040
# 21            0.687584            0.671928          0.689413         0.011159
# 22            0.687584            0.671928          0.689413         0.011159
# 23            0.687584            0.671928          0.689413         0.011159
# 24            0.703330            0.680219          0.693838         0.007867
# 25            0.703330            0.680219          0.693838         0.007867
# 26            0.703330            0.680219          0.693838         0.007867
# 27            0.693187            0.685306          0.694201         0.005524
# 28            0.693187            0.685306          0.694201         0.005524
# 29            0.693187            0.685306          0.694201         0.005524
# 30            0.703573            0.706268          0.723003         0.015379
# 31            0.703573            0.706268          0.723003         0.015379
# 32            0.703573            0.706268          0.723003         0.015379
# 33            0.723328            0.698957          0.728139         0.017472
# 34            0.723328            0.698957          0.728139         0.017472
# 35            0.723328            0.698957          0.728139         0.017472
# 36            0.737617            0.710884          0.734550         0.013970
# 37            0.737617            0.710884          0.734550         0.013970
# 38            0.737617            0.710884          0.734550         0.013970
# 39            0.736911            0.717216          0.739974         0.013969
# 40            0.736911            0.717216          0.739974         0.013969
# 41            0.736911            0.717216          0.739974         0.013969
# 42            0.762087            0.748261          0.760066         0.008072
# 43            0.762087            0.748261          0.760066         0.008072
# 44            0.762087            0.748261          0.760066         0.008072
# 45            0.773460            0.764623          0.779423         0.010014
# 46            0.773460            0.764623          0.779423         0.010014
# 47            0.773460            0.764623          0.779423         0.010014
# 48            0.797946            0.773513          0.792438         0.009956
# 49            0.797946            0.773513          0.792438         0.009956
# 50            0.797946            0.773513          0.792438         0.009956
# 51            0.803086            0.775290          0.795938         0.010660
# 52            0.803086            0.775290          0.795938         0.010660
# 53            0.803086            0.775290          0.795938         0.010660
